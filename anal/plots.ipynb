# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
seaborn.set_theme(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1.2, color_codes=True, rc=None)

# %%
# Load datasets

# %%
j = 1

# %%
path = '../run'+str(j)

# %%
train_log = np.loadtxt(path + '/train_log.npy')
test_log = np.loadtxt(path + '/test_log.npy')
acc = np.loadtxt(path + '/acc.npy')

# %%
# Plots

# %%
sns.lineplot(train_log)
sns.lineplot(test_log)
sns.lineplot(acc)
# Out:
# <Axes: >
